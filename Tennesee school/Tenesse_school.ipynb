# %%
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv("data.csv")
df.head(10)
# Out:
#                              name  school_rating    size  reduced_lunch  \
# 0     Allendale Elementary School            5.0   851.0           10.0
# 1             Anderson Elementary            2.0   412.0           71.0
# 2                Avoca Elementary            4.0   482.0           43.0
# 3                   Bailey Middle            0.0   394.0           91.0
# 4             Barfield Elementary            4.0   948.0           26.0
# 5  Barkers Mill Elementary School            4.0   893.0           48.0
# 6            Barksdale Elementary            4.0   580.0           58.0
# 7                Beech Elementary            5.0   612.0           16.0
# 8        Beech Senior High School            4.0  1274.0           21.0
# 9                 Bellevue Middle            3.0   680.0           50.0
#
#    state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# 0                 90.2                 95.8             15.7         Public
# ...

# %%
df[['reduced_lunch','school_rating']].groupby(['school_rating']).describe().unstack()
# Out:
#                       school_rating
# reduced_lunch  count  0.0              43.000000
#                       1.0              40.000000
#                       2.0              44.000000
#                       3.0              56.000000
#                       4.0              86.000000
#                       5.0              78.000000
#                mean   0.0              83.581395
#                       1.0              74.950000
#                       2.0              64.272727
#                       3.0              50.285714
#                       4.0              41.000000
#                       5.0              21.602564
#                std    0.0               8.813498
#                       1.0              11.644191
#                       2.0              11.956051
#                       3.0              13.550866
#                       4.0              16.681092
#                       5.0              17.651268
# ...

# %%
df[['reduced_lunch','school_rating']].corr()
# Out:
#                reduced_lunch  school_rating
# reduced_lunch       1.000000      -0.815757
# school_rating      -0.815757       1.000000

# %%
df.isnull().any()
# Out:
# name                   False
# school_rating          False
# size                   False
# reduced_lunch          False
# state_percentile_16    False
# state_percentile_15     True
# stu_teach_ratio        False
# school_type            False
# avg_score_15            True
# avg_score_16           False
# full_time_teachers     False
# percent_black          False
# percent_white          False
# percent_asian          False
# percent_hispanic       False
# dtype: bool

# %%
df[['state_percentile_15','avg_score_15']].dtypes
# Out:
# state_percentile_15    float64
# avg_score_15           float64
# dtype: object

# %%
df[['state_percentile_15','avg_score_15']]
# Out:
#      state_percentile_15  avg_score_15
# 0                   95.8          89.4
# 1                   37.3          43.0
# 2                   83.6          75.7
# 3                    1.0           2.1
# 4                   89.2          81.3
# ..                   ...           ...
# 342                 65.2          61.4
# 343                 97.0          92.0
# 344                 76.7          69.4
# 345                 97.1          89.8
# 346                  1.2           2.7
#
# [347 rows x 2 columns]

# %%
impute_df = df[['state_percentile_15','avg_score_15']]
mean_imputation = SimpleImputer(missing_values=np.nan,strategy='mean',add_indicator = True)
new_df = mean_imputation.fit_transform(impute_df)

# %%
print (type(new_df))
# Out:
# <class 'numpy.ndarray'>

# %%
print (new_df.shape)
# Out:
# (347, 4)

# %%
print (new_df[:100])
# Out:
# [[95.8        89.4         0.          0.        ]
#  [37.3        43.          0.          0.        ]
#  [83.6        75.7         0.          0.        ]
#  [ 1.          2.1         0.          0.        ]
#  [89.2        81.3         0.          0.        ]
#  [76.4        69.4         0.          0.        ]
#  [74.6        68.          0.          0.        ]
#  [93.4        85.9         0.          0.        ]
#  [77.9        67.2         0.          0.        ]
#  [55.5        55.8         0.          0.        ]
#  [ 2.9         6.3         0.          0.        ]
#  [63.8        59.9         0.          0.        ]
#  [62.8        58.8         0.          0.        ]
#  [90.3        82.5         0.          0.        ]
#  [66.2        62.1         0.          0.        ]
#  [87.1        77.2         0.          0.        ]
#  [54.1        53.2         0.          0.        ]
#  [59.2        58.1         0.          0.        ]
# ...
